# %% [markdown]
# <h1>Laboratory work №3</h1>
# <h2>Satanove Munira AIN-3-21</h2>
# <h3>Library matplotlib and various graphics</h3>

# %%
import matplotlib.pyplot as plt
import numpy as np 

# Turn on graphing in the notebook
# %matplotlib inline

# %% [markdown]
# Graph of a quadratic function

# %%
x = np.linspace(-5, 5, 100)
y = x**2
plt.figure(figsize=(8, 4))  # Set the size of the shape
plt.plot(x, y)
plt.xlabel('X-ось')
plt.ylabel('Y-ось')
plt.title('График квадратичной функции')

plt.tight_layout()
plt.show()

# %% [markdown]
# Graph of a harmonic function

# %%
x = np.linspace(0, 2*np.pi, 100)
y = np.sin(x)
plt.figure(figsize=(8, 4))
plt.plot(x, y)
plt.xlabel('X-ось')
plt.ylabel('Y-ось')
plt.title('График гармонической функции')

plt.tight_layout()
plt.show()

# %% [markdown]
# Split into two fields

# %%
plt.subplot(1, 2, 1)
x = np.linspace(-5, 5, 100)
y_harmonic = np.sin(x)
plt.plot(x, y_harmonic)
plt.xlabel('X-ось')
plt.ylabel('Y-ось')
plt.title('График гармонической функции')

plt.subplot(1, 2, 2)
x = np.linspace(-5, 5, 100)
y_quadratic = x**2
plt.plot(x, y_quadratic)
plt.xlabel('X-ось')
plt.ylabel('Y-ось')
plt.title('График квадратичной функции')

plt.tight_layout()
plt.show()

# %% [markdown]
# Graphs on one coordinate plane with legend

# %%
x = np.linspace(-5, 5, 100)
y_harmonic = np.sin(x)
y_quadratic = x**2
plt.figure(figsize=(8, 4))
plt.plot(x, y_harmonic, label='Гармоническая функция')
plt.plot(x, y_quadratic, label='Квадратичная функция')
plt.xlabel('X-ось')
plt.ylabel('Y-ось')
plt.title('Графики функций')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Graph of parametric function

# %%
t = np.linspace(0, 4*np.pi, 100)
x_parametric = np.cos(3*t)
y_parametric = np.sin(2*t)
plt.figure(figsize=(8, 4))
plt.plot(x_parametric, y_parametric)
plt.xlabel('X-ось')
plt.ylabel('Y-ось')
plt.title('График параметрической функции')

plt.tight_layout()
plt.show()

# %% [markdown]
# Bar chart

# %%
years = [2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
min_income = [4341.15, 4599.21, 4981.51, 5182.99, 4794.34, 4900.79, 4792.54, 4806.32, 5358.53, 6268.31, 7178.32]
plt.figure(figsize=(10, 6))
plt.bar(years, min_income)
plt.xlabel('Год')
plt.ylabel('Прожиточный минимум')
plt.title('Столбиковая диаграмма прожиточного минимума в КР (2012-2022)')

plt.tight_layout()
plt.show()

# %% [markdown]
# Pie chart

# %%
categories = ['2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022']
min_income = [4341.15, 4599.21, 4981.51, 5182.99, 4794.34, 4900.79, 4792.54, 4806.32, 5358.53, 6268.31, 7178.32]
plt.figure(figsize=(8, 8))
plt.pie(min_income, labels=categories, autopct='%1.1f%%')
plt.title('Круговая диаграмма прожиточного минимума в КР (2012-2022)')

plt.tight_layout()
plt.show()

# %% [markdown]
# Frame surface

# %%
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
x, y = np.meshgrid(x, y)
z = np.sin(x) + np.cos(y)
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, z, cmap='viridis')
ax.set_xlabel('X-ось')
ax.set_ylabel('Y-ось')
ax.set_zlabel('Z-ось')
plt.title('Каркасная поверхность')
# Out:
# Text(0.5, 0.92, 'Каркасная поверхность')
